# %% [markdown]
# Anomaly detection is the process of finding abnormalities in data, also referred to as outlier detection.

# %% [markdown]
# Use Autoencoder to implement anomaly detection. Build the model by using:

# %% [markdown]
# ### 1. Import required libraries

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 10, 8


RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# ### 2. Upload / access the dataset
# Here we are using the credit card dataset to detect fradulent transactions.

# %% [markdown]
# Data Exploration

# %%
#df = pd.read_csv('/content/creditcard.csv')
df = pd.read_csv("creditcard.csv", error_bad_lines=False)
#df = pd.read_csv('creditcard.csv', index_col=0),
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Data Preparation

# %%
data = df.drop(['Time'], axis=1)
data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (66455, 29)

# %% [markdown]
# ### 3. Encoder converts it into latent representation
# ### 4. Decoder networks convert it back to the original input

# %%
input_dim = X_train.shape[1]
encoding_dim = 14
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# ### 5. Compile the models with Optimizer, Loss, and Evaluation Metrics

# %% [markdown]
# Training

# %%
nb_epoch = 100
batch_size = 32
autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 2077/2077 [==============================] - 9s 4ms/step - loss: 0.8704 - accuracy: 0.4198 - val_loss: 0.8771 - val_accuracy: 0.5518
# Epoch 2/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.7682 - accuracy: 0.5817 - val_loss: 0.8343 - val_accuracy: 0.5974
# Epoch 3/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.7422 - accuracy: 0.6121 - val_loss: 0.8165 - val_accuracy: 0.6184
# Epoch 4/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7292 - accuracy: 0.6243 - val_loss: 0.8059 - val_accuracy: 0.6243
# Epoch 5/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7213 - accuracy: 0.6328 - val_loss: 0.8010 - val_accuracy: 0.6183
# Epoch 6/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7158 - accuracy: 0.6397 - val_loss: 0.7949 - val_accuracy: 0.6354
# Epoch 7/100
# 2077/2077 [==============================] - 8s 4ms/step - loss: 0.7121 - accuracy: 0.6428 - val_loss: 0.7911 - val_accuracy: 0.6464
# Epoch 8/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.7091 - accuracy: 0.6452 - val_loss: 0.7890 - val_accuracy: 0.6399
# Epoch 9/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7067 - accuracy: 0.6489 - val_loss: 0.7881 - val_accuracy: 0.6362
# Epoch 10/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.7047 - accuracy: 0.6512 - val_loss: 0.7838 - val_accuracy: 0.6480
# Epoch 11/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7034 - accuracy: 0.6537 - val_loss: 0.7819 - val_accuracy: 0.6640
# Epoch 12/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7021 - accuracy: 0.6587 - val_loss: 0.7810 - val_accuracy: 0.6638
# Epoch 13/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.7008 - accuracy: 0.6590 - val_loss: 0.7855 - val_accuracy: 0.6460
# Epoch 14/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6993 - accuracy: 0.6595 - val_loss: 0.7763 - val_accuracy: 0.6608
# Epoch 15/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6965 - accuracy: 0.6643 - val_loss: 0.7751 - val_accuracy: 0.6650
# Epoch 16/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6946 - accuracy: 0.6670 - val_loss: 0.7719 - val_accuracy: 0.6713
# Epoch 17/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6931 - accuracy: 0.6675 - val_loss: 0.7718 - val_accuracy: 0.6663
# Epoch 18/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.
100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6813 - accuracy: 0.6736 - val_loss: 0.7554 - val_accuracy: 0.6733
# Epoch 80/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6813 - accuracy: 0.6756 - val_loss: 0.7574 - val_accuracy: 0.6777
# Epoch 81/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6816 - accuracy: 0.6766 - val_loss: 0.7556 - val_accuracy: 0.6816
# Epoch 82/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6814 - accuracy: 0.6767 - val_loss: 0.7550 - val_accuracy: 0.6787
# Epoch 83/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6811 - accuracy: 0.6761 - val_loss: 0.7548 - val_accuracy: 0.6784
# Epoch 84/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6812 - accuracy: 0.6756 - val_loss: 0.7560 - val_accuracy: 0.6723
# Epoch 85/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6812 - accuracy: 0.6758 - val_loss: 0.7563 - val_accuracy: 0.6678
# Epoch 86/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6812 - accuracy: 0.6763 - val_loss: 0.7556 - val_accuracy: 0.6768
# Epoch 87/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6810 - accuracy: 0.6748 - val_loss: 0.7550 - val_accuracy: 0.6781
# Epoch 88/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6812 - accuracy: 0.6751 - val_loss: 0.7556 - val_accuracy: 0.6767
# Epoch 89/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6813 - accuracy: 0.6766 - val_loss: 0.7564 - val_accuracy: 0.6797
# Epoch 90/100
# 2077/2077 [==============================] - 8s 4ms/step - loss: 0.6814 - accuracy: 0.6751 - val_loss: 0.7548 - val_accuracy: 0.6780
# Epoch 91/100
# 2077/2077 [==============================] - 8s 4ms/step - loss: 0.6812 - accuracy: 0.6759 - val_loss: 0.7553 - val_accuracy: 0.6825
# Epoch 92/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6811 - accuracy: 0.6742 - val_loss: 0.7541 - val_accuracy: 0.6822
# Epoch 93/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6812 - accuracy: 0.6763 - val_loss: 0.7561 - val_accuracy: 0.6808
# Epoch 94/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6814 - accuracy: 0.6765 - val_loss: 0.7553 - val_accuracy: 0.6712
# Epoch 95/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6808 - accuracy: 0.6757 - val_loss: 0.7547 - val_accuracy: 0.6790
# Epoch 96/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6811 - accuracy: 0.6768 - val_loss: 0.7566 - val_accuracy: 0.6797
# Epoch 97/100
# 2077/2077 [==============================] - 7s 3ms/step - loss: 0.6809 - accuracy: 0.6752 - val_loss: 0.7549 - val_accuracy: 0.6834
# Epoch 98/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6806 - accuracy: 0.6759 - val_loss: 0.7540 - val_accuracy: 0.6839
# Epoch 99/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6811 - accuracy: 0.6751 - val_loss: 0.7549 - val_accuracy: 0.6835
# Epoch 100/100
# 2077/2077 [==============================] - 7s 4ms/step - loss: 0.6806 - accuracy: 0.6753 - val_loss: 0.7554 - val_accuracy: 0.6774

# %% [markdown]
# Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 521/521 [==============================] - 1s 1ms/step
#        reconstruction_error    true_class
# count          16656.000000  16656.000000
# mean               0.754517      0.002041
# std                3.773452      0.045136
# min                0.034955      0.000000
# 25%                0.195798      0.000000
# 50%                0.359008      0.000000
# 75%                0.596659      0.000000
# max              153.937485      1.000000

# %% [markdown]
# Reconstruction Error

# %% [markdown]
# Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
threshold = 2.9
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
